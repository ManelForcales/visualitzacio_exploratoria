# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df= pd.read_csv('./dades/DelayedFlights.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4   1829.0        1755   1959.0
# 4  2008      1           3          4   1940.0        1915   2121.0
#
#    CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0        2225            WN        335  N712SW              128.0
# 1        1000            WN       3231  N772SW              128.0
# 2         750            WN        448  N428WN               96.0
# 3        1925            WN       3920  N464WN               90.0
# 4        2110            WN        378  N726SW              101.0
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# 0           150.0    116.0     -14.0       8.0    IAD  TPA       810     4.0
# 1           145.0    113.0       2.0      19.0    IAD  TPA       810     5.0
# 2            90.0     76.0      14.0       8.0    IND  BWI       515     3.0
# 3            90.0     77.0      34.0      34.0    IND  BWI       515     3.0
# 4           115.0     87.0      11.0      25.0    IND  JAX       688     4.0
#
#    TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  WeatherDelay  \
# 0      8.0          0                N         0           NaN           NaN
# 1     10.0          0                N         0           NaN           NaN
# 2     17.0          0                N         0           NaN           NaN
# 3     10.0          0                N         0           2.0           0.0
# 4     10.0          0                N         0           NaN           NaN
#
#    NASDelay  SecurityDelay  LateAircraftDelay
# 0       NaN            NaN                NaN
# 1       NaN            NaN                NaN
# 2       NaN            NaN                NaN
# 3       0.0            0.0               32.0
# 4       NaN            NaN                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 29 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Year               int64
#  1   Month              int64
#  2   DayofMonth         int64
#  3   DayOfWeek          int64
#  4   DepTime            float64
#  5   CRSDepTime         int64
#  6   ArrTime            float64
#  7   CRSArrTime         int64
#  8   UniqueCarrier      object
#  9   FlightNum          int64
#  10  TailNum            object
#  11  ActualElapsedTime  float64
#  12  CRSElapsedTime     float64
#  13  AirTime            float64
#  14  ArrDelay           float64
#  15  DepDelay           float64
#  16  Origin             object
#  17  Dest               object
#  18  Distance           int64
#  19  TaxiIn             float64
#  20  TaxiOut            float64
#  21  Cancelled          int64
#  22  CancellationCode   object
#  23  Diverted           int64
#  24  CarrierDelay       float64
#  25  WeatherDelay       float64
#  26  NASDelay           float64
#  27  SecurityDelay      float64
#  28  LateAircraftDelay  float64
# dtypes: float64(14), int64(10), object(5)
# memory usage: 428.5+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# # Exercici 1
#
# Crea almenys una visualització per:
#
#     Una variable categòrica (UniqueCarrier)
#     Una variable numèrica (ArrDelay)
#     Una variable numèrica i una categòrica (ArrDelay i UniqueCarrier)
#     Dues variables numèriques (ArrDelay i DepDelay)
#     Tres variables (ArrDelay, DepDelay i UniqueCarrier)
#     Més de tres variables (ArrDelay, DepDelay, AirTime i UniqueCarrier).

# %%
df['UniqueCarrier'].value_counts(ascending=True).plot(kind='bar')
# numero de veces que aparece el UniqueCarrier
#sns.boxplot(x="UniqueCarrier", y="ArrDelay", data=df)
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['ArrDelay'])
# Out:
# <AxesSubplot:xlabel='ArrDelay', ylabel='Density'>

# %%
sns.catplot(x="UniqueCarrier", y='ArrDelay',kind='box', data=df)
#sns.boxplot(x="UniqueCarrier", y="ArrDelay", data=df)
# AirrDelay values en funcion de la variable categorica UniqueCarrier
# se pueden ver muchos outliers

# %%
sns.histplot(data=df,x='ArrDelay',bins=1000)
#distribucion de puntos de la variable numerica ArrDelay
# la mayoria de ArrDelay estan cercade -10, 500 pero hay outliers
# Out:
# <AxesSubplot:xlabel='ArrDelay', ylabel='Count'>

# %%
#plot1 = sns.catplot(data=df, kind="bar",x="UniqueCarrier", y="AirTime")
plot1 = sns.barplot(data=df,x="UniqueCarrier", y="AirTime")

# %%
sns.scatterplot(x="ArrDelay", y="DepDelay", data=df)
# Out:
# <AxesSubplot:xlabel='ArrDelay', ylabel='DepDelay'>

# %%
sca = sns.scatterplot(x='ArrDelay',y='DepDelay',hue='UniqueCarrier',data=df)
# Out:
# /home/vant/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.pairplot(df[['ArrDelay', 'DepDelay', 'AirTime', 'UniqueCarrier']])

# %% [markdown]
# # Exercici 2
#
# Exporta els gràfics com imatges o com html.

# %%
plot1.figure.savefig('output_fig1.png')
sca.figure.savefig('scatter_data.png')
# Out:
# <ipython-input-26-6fedda562331>:2: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   sca.figure.savefig('scatter_data.png')

# %% [markdown]
# # Exercici 3
#
# Exporta el data set net i amb les noves columnes a Excel.

# %%
df.to_csv("./dades/clean_data.csv")

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 94 kB/s eta 0:00:011
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
df.iloc[:1500].to_excel("./dades/clean_data.xlsx",index=False,header=True)

# %% [markdown]
# # Exercici 4
#
# Integra les visualitzacions gràfiques, en la tasca 5, del Sprint 3.

# %%
# ja les he integrat en la tasca 5 del spint 3
